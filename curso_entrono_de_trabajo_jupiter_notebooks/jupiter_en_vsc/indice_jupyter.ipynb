# %% [markdown]
# #### Markdown es un lenguaje de marcado ligero que permite crear documentos con formato de manera sencilla. A continuación se muestran las principales características y ejemplos de uso para usarlos en jupiter con esto y algunos comandos mas podemos hacer una buena documentaicon usando jupyter.
# ---
#
# ## Encabezados
#
# # Encabezado 1
# ## Encabezado 2
# ### Encabezado 3
# #### Encabezado 4
# ##### Encabezado 5
# ###### Encabezado 6
#
# ---
#
# ## Énfasis
#
# *Texto en cursiva*
# **Texto en negrita**
# ***Negrita y cursiva***
# ~~Texto tachado~~
#
# ---
#
# ## Listas
#
# ### Lista desordenada
#
# - Elemento 1
# - Elemento 2
#     - Sub-elemento
# * Elemento alternativo
#
# ### Lista ordenada
#
# 1. Primer elemento
# 2. Segundo elemento
#      1. Sub-elemento
#
# ---
#
# ## Enlaces
#
# [enlace a Github](https://github.com)
#
#
# ## Imágenes
#
# ![Texto alternativo](https://i0.wp.com/puppis.blog/wp-content/uploads/2020/02/Particularidades-de-los-felinos.jpg?resize=1024%2C683&ssl=1)
#
#
# ---
#
# ## Citas
#
# > Esto es una cita.
# >> Cita anidada.
#
# ---
#
# ## Tablas
#
#
# | Columna 1 | Columna 2 |
# |-----------|-----------|
# | Dato 1    | Dato 2    |
# | Dato 3    | Dato 4    |
#
# ---
#
# ## Tareas
#
# - [x] Tarea completada
# - [ ] Tarea pendiente
#
# ---
#
# ## HTML en Markdown
#
# <p style="color:blue">Esto es HTML dentro de Markdown</p>
#
# ---
#
# ## Referencias
#
# - [Guía oficial de Markdown](https://www.markdownguide.org/basic-syntax/)
# - [Documentación de GitHub Markdown](https://docs.github.com/es/github/writing-on-github)
